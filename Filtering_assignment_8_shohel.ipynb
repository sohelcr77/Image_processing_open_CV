# %% [markdown]
# # Make a custom filter and apply it on an image. Explain it's purpose ?
#
# # OT: Apply Gaussian blur on an image ?

# %%
# Importing required library for processing

import cv2
import numpy as np
from matplotlib import pyplot as plt

#  storing image into image_path variable and Loading the image

image_path= "/content/drive/MyDrive/Computer Vision /111.jpeg"
image = cv2.imread(image_path)

# Creating a RGB and Gray Scale Image for Comparing Results
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)



# Define different custom filter kernels (I want to Blur the loaded image )

blur_kernel1 = np.ones((9,9), dtype=np.float32)/81

blur_kernel2 = np.ones((25,25), dtype=np.float32)/(25*25)



# Applying the custom filters using cv2.filter2D function through different dimension of Kernel

filtered_image1 = cv2.filter2D(image_rgb, -1, blur_kernel1)
filtered_image2= cv2.filter2D(image_rgb, -1, blur_kernel2)



# Displaying the original and filtered images
plt.figure(figsize=(10, 15))


plt.subplot(1, 3, 1)
plt.title("Filtered Image (9*9)")
plt.imshow(filtered_image3, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Filtered Image (25*25)")
plt.imshow(filtered_image2, cmap='gray')
plt.axis('off')


plt.subplot(1, 3, 3)
plt.title("Original Image")
plt.imshow(image_rgb)
plt.axis('off')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Now applying Gaussian blur on an image

# %%
# applying gaussian blur on loaded image (trying different parameters for optimum result)

image_gaussian1 = cv2.GaussianBlur(image_rgb,(3,3),1)
image_gaussian2 = cv2.GaussianBlur(image_rgb,(21,21),0)
image_gaussian3 = cv2.GaussianBlur(image_rgb,(23,23),1)
image_gaussian4 = cv2.GaussianBlur(image_rgb,(33,33),0) # Here Blur is Visible and High


# Displaying Different  Gaussian Blurred  images
plt.figure(figsize=(10, 20))


plt.subplot(1, 4, 1)
plt.title("Gaussian 1 (3*3) Sig-1")
plt.xlabel('Blur effect is Invisible')
plt.imshow(image_gaussian1)

plt.subplot(1, 4, 2)
plt.title("Gaussian 2 (21*21) Sig-0")
plt.xlabel('Blur effect is visible but Low')
plt.imshow(image_gaussian2)

plt.subplot(1, 4, 3)
plt.title("Gaussian 3 (23*23) Sig-1")
plt.xlabel('Blur effect is Invisible')
plt.imshow(image_gaussian3)

plt.subplot(1, 4, 4)
plt.title("Gaussian 4 (33*33) Sig-0")
plt.xlabel('Blur effect is visible and High')
plt.imshow(image_gaussian4)


plt.tight_layout()
plt.show()
